# %% [markdown]
# <a href="https://colab.research.google.com/github/syedshagulhameed13102005/Digital_portfolio/blob/main/Square%20error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Square error

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Generate sample data
np.random.seed(0)
X = np.random.rand(100)
y_true = 3 * X + 2
y_pred = 3 * X + 2 + np.random.randn(100) * 0.5

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_true, y_pred)
print("Mean Squared Error (MSE):", mse)

# Plot the data
plt.scatter(X, y_true, label="True Values")
plt.scatter(X, y_pred, label="Predicted Values")
plt.plot(X, y_true, color="red", label="True Line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("True vs Predicted Values")
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE): 0.25744043102686853
